# %% [markdown]
# # ACCESS-NRI Intake catalog for loading model output

# %% [markdown]
# This tutorial demonstrates how to use the ACCESS-NRI Intake catalog to load model or other output.
#
# ⚠️ **Membership to project `xp65` is required to access the ACCESS-NRI Intake catalog** ⚠️
#
# This is a concise version of the longer [ACCESS-NRI Intake catalog documentation](https://access-nri-intake-catalog.readthedocs.io/) and related [COSIMA training workshop](https://github.com/ACCESS-Hive/cosima-training-workshop-2023/blob/main/Intake.ipynb). Users are encouraged to refer to these for more detail and demonstrations.
#
# Requirements: The `conda/analysis3` module from `/g/data/xp65/public/modules`.

# %% [markdown]
# # Start a dask Client
#
# This is not specific to using the ACCESS-NRI Intake catalog, but it's useful!

# %%
from os import environ
environ["PYTHONWARNINGS"] = "ignore"

# %%
from dask.distributed import Client

client = Client(threads_per_worker=1)
client
# Out:
# <Client: 'tcp://127.0.0.1:35479' processes=48 threads=48, memory=188.56 GiB>

# %% [markdown]
# # Opening and searching the catalog

# %% [markdown]
# To use the ACCESS-NRI Intake catalog, we need to import `intake`

# %%
import intake

# %% [markdown]
# We can open the catalog as follows

# %%
catalog = intake.cat.access_nri

# %% [markdown]
# The returned object `catalog` is an instance of the ACCESS-NRI Intake catalog that we can use to find and load data.

# %% [markdown]
# Printing the `catalog` object will return a dataframe of experiments that you can browse:

# %%
catalog
# Out:
# <p><strong>access_nri catalog with 120 source(s) across 2941 rows</strong>:</p> <div style='max-height: 300px; overflow: auto; width: fit-content'><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>model</th>
#       <th>description</th>
#       <th>realm</th>
#       <th>frequency</th>
#       <th>variable</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>01deg_jra55_ryf_Control</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1° ACCESS-OM2 repeat year forcing control run for the simulations performed in Huguenin et al. (2024, GRL)}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{fx, 1mon}</td>
#       <td>{total_ocean_melt, total_ocean_calving_heat, xu_ocean, HTN, u, total_ocean_evap_heat, total_ocean_salt, aicen_m, grid_yt_ocean, total_ocean_runoff_heat, alidf_ai_m, average_T2, sfc_hflux_pme, sss_...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55_ryf_ENFull</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.1° ACCESS-OM2 El Níño run for the simulations performed in Huguenin et al. (2024, GRL)}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{fx, 1mon}</td>
#       <td>{total_ocean_melt, total_ocean_calving_heat, xu_ocean, HTN, u, total_ocean_evap_heat, total_ocean_salt, aicen_m, grid_yt_ocean, total_ocean_runoff_heat, alidf_ai_m, average_T2, sfc_hflux_pme, sss_...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55_ryf_LNFull</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.1° ACCESS-OM2 La Níña run for the simulations performed in Huguenin et al. (2024, GRL)}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{fx, 1mon}</td>
#       <td>{total_ocean_melt, total_ocean_calving_heat, xu_ocean, HTN, u, total_ocean_evap_heat, total_ocean_salt, aicen_m, grid_yt_ocean, total_ocean_runoff_heat, alidf_ai_m, average_T2, sfc_hflux_pme, sss_...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991)}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1mon, 3hr, fx, 1day, 3mon}</td>
#       <td>{total_ocean_melt, total_ocean_calving_heat, xu_ocean, bih_fric_u, u, total_ocean_evap_heat, HTN, total_ocean_salt, passive_adelie, aicen_m, grid_yt_ocean, total_ocean_runoff_heat, alidf_ai_m, ave...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_easterlies_down10</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991) and zonal/meridional wind speed around Antarctica decreased by 10%.}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{fx, 1mon, 1day}</td>
#       <td>{total_ocean_melt, total_ocean_calving_heat, xu_ocean, bih_fric_u, u, total_ocean_evap_heat, HTN, total_ocean_salt, aicen_m, grid_yt_ocean, total_ocean_runoff_heat, alidf_ai_m, average_T2, sfc_hfl...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_easterlies_up10</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991) and zonal/meridional wind speed around Antarctica increased by 10%.}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{fx, 1mon, 1day}</td>
#       <td>{total_ocean_melt, total_ocean_calving_heat, xu_ocean, bih_fric_u, u, total_ocean_evap_heat, HTN, total_ocean_salt, aicen_m, grid_yt_ocean, total_ocean_runoff_heat, alidf_ai_m, average_T2, sfc_hfl...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_easterlies_up10_meridional</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991) and meridional wind speed around Antarctica increased by 10%.}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{fx, 1mon, 1day}</td>
#       <td>{total_ocean_melt, total_ocean_calving_heat, xu_ocean, bih_fric_u, u, total_ocean_evap_heat, HTN, total_ocean_salt, aicen_m, grid_yt_ocean, total_ocean_runoff_heat, alidf_ai_m, average_T2, sfc_hfl...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_easterlies_up10_zonal</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991) and zonal wind speed around Antarctica increased by 10%.}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{fx, 1mon, 1day}</td>
#       <td>{total_ocean_melt, total_ocean_calving_heat, xu_ocean, bih_fric_u, u, total_ocean_evap_heat, HTN, total_ocean_salt, aicen_m, grid_yt_ocean, total_ocean_runoff_heat, alidf_ai_m, average_T2, sfc_hfl...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_qian_wthmp</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Future perturbations with wind, thermal and meltwater forcing, branching off 01deg_jra55v13_ryf9091, as described in Li et al.  2023, https://www.nature.com/articles/s41586-023-05762-w}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{fx, 1mon}</td>
#       <td>{total_ocean_melt, total_ocean_calving_heat, xu_ocean, HTN, u, total_ocean_evap_heat, total_ocean_salt, aicen_m, grid_yt_ocean, total_ocean_runoff_heat, alidf_ai_m, average_T2, sfc_hflux_pme, sss_...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_qian_wthp</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Future perturbation with wind and thermal forcing, branching off 01deg_jra55v13_ryf9091, as described in Li et al.  2023, https://www.nature.com/articles/s41586-023-05762-w}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{fx, 1mon}</td>
#       <td>{total_ocean_melt, total_ocean_calving_heat, xu_ocean, HTN, u, total_ocean_evap_heat, total_ocean_salt, aicen_m, grid_yt_ocean, total_ocean_runoff_heat, alidf_ai_m, average_T2, sfc_hflux_pme, sss_...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_weddell_down2</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Weddell Sea decreased meltwater perturbation experiment, branched off 01deg_jra55v13_ryf9091. }</td>
#       <td>{ocean, seaIce}</td>
#       <td>{fx, 1mon, 1day}</td>
#       <td>{total_ocean_melt, total_ocean_calving_heat, xu_ocean, bih_fric_u, u, total_ocean_evap_heat, HTN, total_ocean_salt, aicen_m, grid_yt_ocean, total_ocean_runoff_heat, alidf_ai_m, average_T2, sfc_hfl...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_weddell_up1</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Weddell Sea increased meltwater perturbation experiment, branched off 01deg_jra55v13_ryf9091. }</td>
#       <td>{ocean, seaIce}</td>
#       <td>{fx, 1mon, 1day}</td>
#       <td>{total_ocean_melt, total_ocean_calving_heat, xu_ocean, bih_fric_u, u, total_ocean_evap_heat, HTN, total_ocean_salt, aicen_m, grid_yt_ocean, total_ocean_runoff_heat, alidf_ai_m, average_T2, sfc_hfl...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Cycle 1 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0 OMIP2 interannual forcing}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{fx, 1mon, 1day}</td>
#       <td>{daidtd_m, total_ocean_melt, total_ocean_calving_heat, xu_ocean, bih_fric_u, u, total_ocean_evap_heat, temp_yflux_adv_int_z, HTN, total_ocean_salt, frzmlt_m, aicen, aicen_m, total_ocean_runoff_hea...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf_cycle2</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Cycle 2 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0 OMIP2 interannual forcing}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{fx, 1mon, 1day}</td>
#       <td>{daidtd_m, total_ocean_melt, xu_ocean, bih_fric_u, u, total_ocean_evap_heat, temp_yflux_adv_int_z,

# %% [markdown]
# You can also search based on the columns in this dataframe to find experiments that are relevant to you. For example, you might be interested in all ACCESS-OM2 experiments that have the variable `"surface_salt"` at daily frequency. There are 6 such experiments currently available through the catalog:

# %%
catalog.search(model="ACCESS-OM2", variable="surface_salt", frequency="1day")
# Out:
# <p><strong>Intake dataframe catalog with 6 source(s) across 6 rows</strong>:</p> <div style='max-height: 300px; overflow: auto; width: fit-content'><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>model</th>
#       <th>description</th>
#       <th>realm</th>
#       <th>frequency</th>
#       <th>variable</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>025deg_era5_iaf</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.25 degree ACCESS-OM2 global model configuration with ERA5 interannual\nforcing (1980-2021)}</td>
#       <td>{ocean}</td>
#       <td>{1day}</td>
#       <td>{surface_salt}</td>
#     </tr>
#     <tr>
#       <th>025deg_era5_ryf</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.25 degree ACCESS-OM2 global model configuration with ERA5 RYF9091 repeat\nyear forcing (May 1990 to Apr 1991)}</td>
#       <td>{ocean}</td>
#       <td>{1day}</td>
#       <td>{surface_salt}</td>
#     </tr>
#     <tr>
#       <th>025deg_jra55_iaf_era5comparison</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.25 degree ACCESS-OM2 global model configuration with JRA55-do v1.5.0\ninterannual forcing (1980-2019)}</td>
#       <td>{ocean}</td>
#       <td>{1day}</td>
#       <td>{surface_salt}</td>
#     </tr>
#     <tr>
#       <th>025deg_jra55_ryf_era5comparison</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.25 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0\nRYF9091 repeat year forcing (May 1990 to Apr 1991)}</td>
#       <td>{ocean}</td>
#       <td>{1day}</td>
#       <td>{surface_salt}</td>
#     </tr>
#     <tr>
#       <th>1deg_era5_iaf</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{1 degree ACCESS-OM2 global model configuration with ERA5 interannual\nforcing (1960-2019)}</td>
#       <td>{ocean}</td>
#       <td>{1day}</td>
#       <td>{surface_salt}</td>
#     </tr>
#     <tr>
#       <th>1deg_jra55_iaf_era5comparison</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{1 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0\ninterannual forcing (1960-2019)}</td>
#       <td>{ocean}</td>
#       <td>{1day}</td>
#       <td>{surface_salt}</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>

# %% [markdown]
# # Opening data

# %% [markdown]
# There are [multiple ways](https://access-nri-intake-catalog.readthedocs.io/en/latest/usage/quickstart.html#loading-intake-sources) to open data from the experiments in `catalog`. Here we'll demonstrate how to do this when you know the name of the experiment you are interested in, since this typical for COSIMA users.

# %% [markdown]
# For example, we can open monthly data for the `surface_salt` variable in the `01deg_jra55v13_ryf9091` experiment as follows:

# %%
experiment = "01deg_jra55v13_ryf9091"
variable = "surface_salt"

# %%
data_ic = catalog[experiment].search(
    variable=variable, 
    frequency="1mon"
).to_dask()
# Out:
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/intake_esm/core.py:301: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   records = grouped.get_group(internal_key).to_dict(orient='records')

# %%
data_ic["surface_salt"]
# Out:
# <xarray.DataArray 'surface_salt' (time: 3360, yt_ocean: 2700, xt_ocean: 3600)> Size: 131GB
# dask.array<concatenate, shape=(3360, 2700, 3600), dtype=float32, chunksize=(1, 675, 900), chunktype=numpy.ndarray>
# Coordinates:
#   * xt_ocean  (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#   * yt_ocean  (yt_ocean) float64 22kB -81.11 -81.07 -81.02 ... 89.89 89.94 89.98
#   * time      (time) object 27kB 1900-01-16 12:00:00 ... 2179-12-16 12:00:00
# Attributes:
#     long_name:      Practical Salinity
#     units:          psu
#     valid_range:    [-10. 100.]
#     cell_methods:   time: mean
#     time_avg_info:  average_T1,average_T2,average_DT
#     standard_name:  sea_surface_salinity

# %% [markdown]
# # Some important facts
#
# There are a few important facts in the ACCESS-NRI Intake catalog that users should be aware of.

# %% [markdown]
# ## 1. The catalog returns `Datasets` (not `Dataarray`s)
#
# This is because with the catalog you can load multiple variables into a single dataset with a single call (when these variables are in the same file). For example,

# %%
data_ic_multivar = catalog[experiment].search(
    variable=["surface_salt", "surface_temp"], 
    frequency="1mon"
).to_dask()
# Out:
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/intake_esm/core.py:301: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   records = grouped.get_group(internal_key).to_dict(orient='records')

# %%
data_ic_multivar
# Out:
# <xarray.Dataset> Size: 261GB
# Dimensions:       (time: 3360, yt_ocean: 2700, xt_ocean: 3600)
# Coordinates:
#   * xt_ocean      (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.85 79.95
#   * yt_ocean      (yt_ocean) float64 22kB -81.11 -81.07 -81.02 ... 89.94 89.98
#   * time          (time) object 27kB 1900-01-16 12:00:00 ... 2179-12-16 12:00:00
# Data variables:
#     surface_temp  (time, yt_ocean, xt_ocean) float32 131GB dask.array<chunksize=(1, 675, 900), meta=np.ndarray>
#     surface_salt  (time, yt_ocean, xt_ocean) float32 131GB dask.array<chunksize=(1, 675, 900), meta=np.ndarray>
# Attributes:
#     filename:                        ocean_month.nc
#     title:                           ACCESS-OM2-01
#     grid_type:                       mosaic
#     grid_tile:                       1
#     intake_esm_vars:                 ['surface_temp', 'surface_salt']
#     intake_esm_attrs:filename:       ocean_month.nc
#     intake_esm_attrs:file_id:        ocean.1mon.nv:2.xt_ocean:3600.xu_ocean:3...
#     intake_esm_attrs:frequency:      1mon
#     intake_esm_attrs:realm:          ocean
#     intake_esm_attrs:_data_format_:  netcdf
#     intake_esm_dataset_key:          ocean.1mon.nv:2.xt_ocean:3600.xu_ocean:3...

# %% [markdown]
# ## 2. The catalog knows which files make up distinct datasets

# %% [markdown]
# The catalog knows which files make up distinct datasets and provides methods to open multiple datasets from a single query. We can run the equivalent to the cell above using the catalog, using `to_dataset_dict()` rather than `to_dask()`. Doing so returns a dictionary containing Datasets of the variable at all the available frequencies (daily and monthly in this case).

# %%
data_ic_multifreq = catalog[experiment].search(variable=variable).to_dataset_dict()
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'file_id'
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/intake_esm/core.py:301: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   records = grouped.get_group(internal_key).to_dict(orient='records')
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/intake_esm/core.py:301: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   records = grouped.get_group(internal_key).to_dict(orient='records')
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/intake_esm/core.py:301: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   records = grouped.get_group(internal_key).to_dict(orient='records')
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3/3 00:10&lt;00:00]
#     </div>

# %%
data_ic_multifreq
# Out:
# {'ocean.1day.nv:2.xt_ocean:3600.xu_ocean:3600.yt_ocean:2700.yu_ocean:2700': <xarray.Dataset> Size: 610GB
#  Dimensions:       (time: 15695, yt_ocean: 2700, xt_ocean: 3600)
#  Coordinates:
#    * xt_ocean      (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.85 79.95
#    * yt_ocean      (yt_ocean) float64 22kB -81.11 -81.07 -81.02 ... 89.94 89.98
#    * time          (time) object 126kB 2137-01-01 12:00:00 ... 2179-12-31 12:0...
#  Data variables:
#      surface_salt  (time, yt_ocean, xt_ocean) float32 610GB dask.array<chunksize=(1, 675, 900), meta=np.ndarray>
#  Attributes:
#      filename:                        ocean_daily.nc
#      title:                           ACCESS-OM2-01
#      grid_type:                       mosaic
#      grid_tile:                       1
#      intake_esm_vars:                 ['surface_salt']
#      intake_esm_attrs:filename:       ocean_daily.nc
#      intake_esm_attrs:file_id:        ocean.1day.nv:2.xt_ocean:3600.xu_ocean:3...
#      intake_esm_attrs:frequency:      1day
#      intake_esm_attrs:realm:          ocean
#      intake_esm_attrs:_data_format_:  netcdf
#      intake_esm_dataset_key:          ocean.1day.nv:2.xt_ocean:3600.xu_ocean:3...,
#  'ocean.1day.nv:2.xt_ocean:3600.yt_ocean:2700': <xarray.Dataset> Size: 3TB
#  Dimensions:       (time: 65885, yt_ocean: 2700, xt_ocean: 3600)
#  Coordinates:
#    * xt_ocean      (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.85 79.95
#    * yt_ocean      (yt_ocean) float64 22kB -81.11 -81.07 -81.02 ... 89.94 89.98
#    * time          (time) object 527kB 1956-04-01 12:00:00 ... 2136-12-31 12:0...
#  Data variables:
#      surface_salt  (time, yt_ocean, xt_ocean) float32 3TB dask.array<chunksize=(1, 675, 900), meta=np.ndarray>
#  Attributes: (12/14)
#      filename:                                ocean_daily.nc
#      title:                                   ACCESS-OM2-01
#      grid_type:                               mosaic
#      grid_tile:                               1
#      intake_esm_vars:                         ['surface_salt']
#      intake_esm_attrs:filename:               ocean_daily.nc
#      ...                                      ...
#      intake_esm_attrs:variable:               average_DT,average_T1,average_T2...
#      intake_esm_attrs:variable_long_name:     Length of average period,Start t...
#      intake_esm_attrs:variable_cell_methods:  ,,,time: mean,time: mean,time: m...
#      intake_esm_attrs:realm:                  ocean
#      intake_esm_attrs:_data_format_:          netcdf
#      intake_esm_dataset_key:                  ocean.1day.nv:2.xt_ocean:3600.yt...,
#  'ocean.1mon.nv:2.xt_ocean:3600.xu_ocean:3600.yt_ocean:2700.yu_ocean:2700': <xarray.Dataset> Size: 131GB
#  Dimensions:       (time: 3360, yt_ocean: 2700, xt_ocean: 3600)
#  Coordinates:
#    * xt_ocean      (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.85 79.95
#    * yt_ocean      (yt_ocean) float64 22kB -81.11 -81.07 -81.02 ... 89.94 89.98
#    * time          (time) object 27kB 1900-01-16 12:00:00 ... 2179-12-16 12:00:00
#  Data variables:
#      surface_salt  (time, yt_ocean, xt_ocean) float32 131GB dask.array<chunksize=(1, 675, 900), meta=np.ndarray>
#  Attributes:
#      filename:                        ocean_month.nc
#      title:                           ACCESS-OM2-01
#      grid_type:                       mosaic
#      grid_tile:                       1
#      intake_esm_vars:                 ['surface_salt']
#      intake_esm_attrs:filename:       ocean_month.nc
#      intake_esm_attrs:file_id:        ocean.1mon.nv:2.xt_ocean:3600.xu_ocean:3...
#      intake_esm_attrs:frequency:      1mon
#      intake_esm_attrs:realm:          ocean
#      intake_esm_attrs:_data_format_:  netcdf
#      intake_esm_dataset_key:          ocean.1mon.nv:2.xt_ocean:3600.xu_ocean:3...}

# %% [markdown]
# Alternatively, multiple datasets can be opened directly into an [xarray-datatree](https://xarray-datatree.readthedocs.io/en/latest/) by calling `to_datatree` rather than `to_dataset_dict` (in an upcoming release, it will be easier for users to control how the groups are structured in the datatree.). E.g.:

# %%
data_ic_datatree = catalog[experiment].search(variable=variable).to_datatree()
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'file_id'
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/intake_esm/core.py:301: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   records = grouped.get_group(internal_key).to_dict(orient='records')
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/intake_esm/core.py:301: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   records = grouped.get_group(internal_key).to_dict(orient='records')
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/intake_esm/core.py:301: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   records = grouped.get_group(internal_key).to_dict(orient='records')
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3/3 00:10&lt;00:00]
#     </div>

# %%
data_ic_datatree
# Out:
# <xarray.DataTree>
# Group: /
# ├── Group: /ocean.1day.nv:2.xt_ocean:3600.xu_ocean:3600.yt_ocean:2700.yu_ocean:2700
# │       Dimensions:       (time: 15695, yt_ocean: 2700, xt_ocean: 3600)
# │       Coordinates:
# │         * xt_ocean      (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.85 79.95
# │         * yt_ocean      (yt_ocean) float64 22kB -81.11 -81.07 -81.02 ... 89.94 89.98
# │         * time          (time) object 126kB 2137-01-01 12:00:00 ... 2179-12-31 12:0...
# │       Data variables:
# │           surface_salt  (time, yt_ocean, xt_ocean) float32 610GB dask.array<chunksize=(1, 675, 900), meta=np.ndarray>
# │       Attributes:
# │           filename:                        ocean_daily.nc
# │           title:                           ACCESS-OM2-01
# │           grid_type:                       mosaic
# │           grid_tile:                       1
# │           intake_esm_vars:                 ['surface_salt']
# │           intake_esm_attrs:filename:       ocean_daily.nc
# │           intake_esm_attrs:file_id:        ocean.1day.nv:2.xt_ocean:3600.xu_ocean:3...
# │           intake_esm_attrs:frequency:      1day
# │           intake_esm_attrs:realm:          ocean
# │           intake_esm_attrs:_data_format_:  netcdf
# │           intake_esm_dataset_key:          ocean.1day.nv:2.xt_ocean:3600.xu_ocean:3...
# ├── Group: /ocean.1day.nv:2.xt_ocean:3600.yt_ocean:2700
# │       Dimensions:       (time: 65885, yt_ocean: 2700, xt_ocean: 3600)
# │       Coordinates:
# │         * xt_ocean      (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.85 79.95
# │         * yt_ocean      (yt_ocean) float64 22kB -81.11 -81.07 -81.02 ... 89.94 89.98
# │         * time          (time) object 527kB 1956-04-01 12:00:00 ... 2136-12-31 12:0...
# │       Data variables:
# │           surface_salt  (time, yt_ocean, xt_ocean) float32 3TB dask.array<chunksize=(1, 675, 900), meta=np.ndarray>
# │       Attributes: (12/14)
# │           filename:                                ocean_daily.nc
# │           title:                                   ACCESS-OM2-01
# │           grid_type:                               mosaic
# │           grid_tile:                               1
# │           intake_esm_vars:                         ['surface_salt']
# │           intake_esm_attrs:filename:               ocean_daily.nc
# │           ...                                      ...
# │           intake_esm_attrs:variable:               average_DT,average_T1,average_T2...
# │           intake_esm_attrs:variable_long_name:     Length of average period,Start t...
# │           intake_esm_attrs:variable_cell_methods:  ,,,time: mean,time: mean,time: m...
# │           intake_esm_attrs:realm:                  ocean
# │           intake_esm_attrs:_data_format_:          netcdf
# │           intake_esm_dataset_key:                  ocean.1day.nv:2.xt_ocean:3600.yt...
# └── Group: /ocean.1mon.nv:2.xt_ocean:3600.xu_ocean:3600.yt_ocean:2700.yu_ocean:2700
#         Dimensions:       (time: 3360, yt_ocean: 2700, xt_ocean: 3600)
#         Coordinates:
#           * xt_ocean      (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.85 79.95
#           * yt_ocean      (yt_ocean) float64 22kB -81.11 -81.07 -81.02 ... 89.94 89.98
#           * time          (time) object 27kB 1900-01-16 12:00:00 ... 2179-12-16 12:00:00
#         Data variables:
#             surface_salt  (time, yt_ocean, xt_ocean) float32 131GB dask.array<chunksize=(1, 675, 900), meta=np.ndarray>
#         Attributes:
#             filename:                        ocean_month.nc
#             title:                           ACCESS-OM2-01
#             grid_type:                       mosaic
#             grid_tile:                       1
#             intake_esm_vars:                 ['surface_salt']
#             intake_esm_attrs:filename:       ocean_month.nc
#             intake_esm_attrs:file_id:        ocean.1mon.nv:2.xt_ocean:3600.xu_ocean:3...
#             intake_esm_attrs:frequency:      1mon
#             intake_esm_attrs:realm:          ocean
#             intake_esm_attrs:_data_format_:  netcdf
#             intake_esm_dataset_key:          ocean.1mon.nv:2.xt_ocean:3600.xu_ocean:3...

# %% [markdown]
# ## 3. The frequency vocabulary:

# %% [markdown]
# In the catalog, frequency follows a standard vocabulary that is very similar to CMIP6:
#
# ```python
# "fx" # fixed
# "subhr" # subhourly
# "<int>hr" # hourly
# "<int>day" # daily
# "<int>mon" # monthly
# "<int>yr" # yearly
# "<int>dec" # decadal
# ```

# %% [markdown]
# ## 4. Method for passing keyword arguments

# %% [markdown]
# With the catalog, keyword argments for xarray's `open_dataset` and `combine_by_coords` functions are passed separately to `to_dask` (or `to_dataset_dict`). For example:

# %%
xarray_open_kwargs=dict(
    chunks={"xt_ocean": -1, "yt_ocean": -1}
)
xarray_combine_by_coords_kwargs=dict(
    compat="override",
    data_vars="minimal",
    coords="minimal"
)

data_ic_kw = catalog[experiment].search(
    variable=variable, 
    frequency="1mon"
).to_dask(
    xarray_open_kwargs=xarray_open_kwargs,
    xarray_combine_by_coords_kwargs=xarray_combine_by_coords_kwargs,
)
# Out:
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/intake_esm/core.py:301: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   records = grouped.get_group(internal_key).to_dict(orient='records')

# %% [markdown]
# ## 5. Catalog does not allow search by start and end date

# %% [markdown]
# It's not possible to query on a time range with the Intake catalog.
#
# We can always slice the time axis afterwards though. That is, with the catalog you'd just do:

# %%
data_ic = catalog[experiment].search(
    variable=variable, 
    frequency="1mon"
).to_dask()

start_time = "2000-01-01"
end_time = "2180-01-01"

data_ic_times = data_ic.sel(time=slice(start_time, end_time))
# Out:
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/intake_esm/core.py:301: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   records = grouped.get_group(internal_key).to_dict(orient='records')

# %% [markdown]
# which takes a few seconds longer.
#
# This difference is acceptable because the opening of datasets is a parallelized task that is done [lazily](https://docs.xarray.dev/en/stable/user-guide/dask.html#parallel-computing-with-dask),  so opening all files and reducing the times using xarray's `sel` methods doesn't add too much overhead. In most cases where the overhead of opening the files seems large, this can be reduced through sensible choices of keyword arguments provided to `open_dataset` and `combine_by_coords` - see the xarray documentation on [Reading multi-file datasets](https://docs.xarray.dev/en/stable/user-guide/io.html#reading-multi-file-datasets) for details.

# %% [markdown]
# # Tips, gotchas and workarounds

# %% [markdown]
# ## 1. Speeding up opening your datasets

# %% [markdown]
# Try passing the following argument to your `to_dask` or `to_dataset_dict` call:
#
# ```python
# xarray_combine_by_coords_kwargs=dict(
#     compat="override",
#     data_vars="minimal",
#     coords="minimal"
# )
# ```
#
# See the xarray documentation on [Reading multi-file datasets](https://docs.xarray.dev/en/stable/user-guide/io.html#reading-multi-file-datasets) for more details about these arguments.

# %% [markdown]
# ## 2. Choosing chunksizes
#
# Correctly choosing chunk sizes when you open datasets will greatly improve the speed of your analysis. Check out the [Chunking tutorial](https://access-nri-intake-catalog.readthedocs.io/en/latest/usage/chunking.html) in the ACCESS-NRI Intake catalog documentation

# %% [markdown]
# ## 3. Loading time-invariant variables

# %% [markdown]
# Many COSIMA experiments include multiple repeated files containing the same fixed frequency data (e.g. grid information). The catalog fails to concatenate these files since they don't contain clear dimension to concatenate along.

# %% [markdown]
# The workaround to the above is to further restrict your search to only return one file. For example, you could only return the file in the `output000` directory with:

# %%
data_ic_fixed = catalog[experiment].search(
    variable='area_t',
    path=".*output000.*"
).to_dask()
# Out:
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/intake_esm/core.py:301: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   records = grouped.get_group(internal_key).to_dict(orient='records')

# %% [markdown]
# ## 4. Determining what can be searched upon in an experiment
#
# You can see what can be `search`ed on within an experiment with:

# %%
catalog[experiment].df.columns.tolist()
# Out:
# ['filename',
#  'path',
#  'file_id',
#  'frequency',
#  'start_date',
#  'end_date',
#  'variable',
#  'variable_long_name',
#  'variable_standard_name',
#  'variable_cell_methods',
#  'variable_units',
#  'realm']

# %% [markdown]
# It can also be helpful sometimes to look at the `catalog[experiment].df` object itself, which is a dataframe of all of the files in the experiment and their metadata

# %%
catalog[experiment].df.head()
# Out:
#           filename  \
# 0  iceh.1900-01.nc
# 1  iceh.1900-02.nc
# 2  iceh.1900-03.nc
# 3         ocean.nc
# 4    ocean_grid.nc
#
#                                                                                                            path  \
# 0  /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v13_ryf9091/output000/ice/OUTPUT/iceh.1900-01.nc
# 1  /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v13_ryf9091/output000/ice/OUTPUT/iceh.1900-02.nc
# 2  /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v13_ryf9091/output000/ice/OUTPUT/iceh.1900-03.nc
# 3              /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v13_ryf9091/output000/ocean/ocean.nc
# 4         /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v13_ryf9091/output000/ocean/ocean_grid.nc
#
#                                                                                                                                                                                                    file_id  \
# 0                                                                                                                                                                    seaIce.1mon.d2:2.nc:5.ni:3600.nj:2700
# 1                                                                                                                                                                    seaIce.1mon.d2:2.nc:5.ni:3600.nj:2700
# 2                                                                                                                                                                    seaIce.1mon.d2:2.nc:5.ni:3600.nj:2700
# 3  ocean.3mon.grid_xt_ocean:3600.grid_xu_ocean:3600.grid_yt_ocean:2700.grid_yu_ocean:2700.neutral:80.neutralrho_edges:81.nv:2.potrho:80.potrho_edges:81.st_edges_ocean:76.st_ocean:75.sw_edges_ocean:76...
# 4                                                                                                                                         ocean.fx.xt_ocean:3600.xu_ocean:3600.yt_ocean:2700.yu_ocean:2700
#
#   frequency            start_date              end_date  \
# 0      1mon  1900-01-01, 00:00:00  1900-02-01, 00:00:00
# 1      1mon  1900-02-01, 00:00:00  1900-03-01, 00:00:00
# 2      1mon  1900-03-01, 00:00:00  1900-04-01, 00:00:00
# 3      3mon  1900-01-01, 00:00:00  1900-04-01, 00:00:00
# 4        fx  1900-04-01, 00:00:00  1900-04-01, 00:00:00
#
#                                                                                                                                                                                                   variable  \
# 0  ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...
# 1  ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...
# 2  ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...
# 3  ['age_global' 'average_DT' 'average_T1' 'average_T2' 'dzt' 'grid_xt_ocean'
#  'grid_xu_ocean' 'grid_yt_ocean' 'grid_yu_ocean' 'neutral'
#  'neutralrho_edges' 'nv' 'pot_rho_0' 'pot_temp' 'potrho' 'potr...
# 4                          ['area_t' 'area_u' 'drag_coeff' 'dxt' 'dxu' 'dyt' 'dyu' 'geolat_c'
#  'geolat_t' 'geolon_c' 'geolon_t' 'ht' 'hu' 'kmt' 'kmu' 'time' 'xt_ocean'
#  'xu_ocean' 'yt_ocean' 'yu_ocean']
#
#                                                                                                                                                                                         variable_long_name  \
# 0  ['angle grid makes with latitude line on U grid'
#  'angle grid makes with latitude line on T grid'
#  'T cell width on East side' 'T cell width on North side'
#  'category maximum thickness' 'T grid ce...
# 1  ['angle grid makes with latitude line on U grid'
#  'angle grid makes with latitude line on T grid'
#  'T cell width on East side' 'T cell width on North side'
#  'category maximum thickness' 'T grid ce...
# 2  ['angle grid makes with latitude line on U grid'
#  'angle grid makes with latitude line on T grid'
#  'T cell width on East side' 'T cell width on North side'
#  'category maximum thickness' 'T grid ce...
# 3  ['Age (global)' 'Length of average period' 'Start time for average period'
#  'End time for average period' 't-cell thickness' 'tcell longitude'
#  'ucell longitude' 'tcell latitude' 'ucell latitude' ...
# 4  ['tracer cell area' 'velocity cell area'
#  'Dimensionless bottom drag coefficient' 'ocean dxt on t-cells'
#  'ocean dxu on u-cells' 'ocean dyt on t-cells' 'ocean dyu on u-cells'
#  'uv latitude' 'trace...
#
#                                                                                                                                                                                     variable_standard_name  \
# 0                                 ['' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' ''
#  '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' ''
#  '' '' '' '' '' '' '']
# 1                                 ['' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' ''
#  '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' ''
#  '' '' '' '' '' '' '']
# 2                                 ['' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' ''
#  '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' ''
#  '' '' '' '' '' '' '']
# 3  ['sea_water_age_since_surface_contact' '' '' '' 'cell_thickness' '' '' ''
#  '' '' '' '' 'sea_water_potential_density'
#  'sea_water_potential_temperature' '' '' '' 'sea_water_salinity' '' '' ''
#  '' '...
# 4                                                                                                                ['' '' '' '' '' '' '' '' '' '' '' 'sea_floor_depth_below_geoid' '' '' ''
#  '' '' '' '' '']
#
#                                                                                                                                                                                      variable_cell_methods  \
# 0  ['' '' '' '' '' '' '' 'time: mean' '' '' 'time: mean' 'time: mean'
#  'time: mean' 'time: mean' 'time: mean' 'time: mean' '' 'time: mean'
#  'time: mean' '' '' '' '' 'time: mean' 'time: mean' 'time: m...
# 1  ['' '' '' '' '' '' '' 'time: mean' '' '' 'time: mean' 'time: mean'
#  'time: mean' 'time: mean' 'time: mean' 'time: mean' '' 'time: mean'
#  'time: mean' '' '' '' '' 'time: mean' 'time: mean' 'time: m...
# 2  ['' '' '' '' '' '' '' 'time: mean' '' '' 'time: mean' 'time: mean'
#  'time: mean' 'time: mean' 'time: mean' 'time: mean' '' 'time: mean'
#  'time: mean' '' '' '' '' 'time: mean' 'time: mean' 'time: m...
# 3  ['time: mean' '' '' '' 'time: mean' '' '' '' '' '' '' '' 'time: mean'
#  'time: mean' '' '' 'time: mean' 'time: mean' '' '' '' '' 'time: mean'
#  'time: mean' 'time: mean' '' '' 'time: mean' 'time: me...
# 4  ['time: point' 'time: point' 'time: point' 'time: point' 'time: point'
#  'time: point' 'time: point' 'time: point' 'time: point' 'time: point'
#  'time: point' 'time: point' 'time: point' 'time: poin...
#
#                                                                                                                                                                                             variable_units  \
# 0  ['radians' 'radians' 'm' 'm' 'm' 'degrees_north' 'degrees_east' 'C'
#  'degrees_north' 'degrees_east' '1' '1' '%' '%' '%' '%' '' 'cm/day'
#  '%/day' 'm' 'm' 'm' 'm' 'W/m^2' 'W/m^2' 'W/m^2' 'cm/day' 'd...
# 1  ['radians' 'radians' 'm' 'm' 'm' 'degrees_north' 'degrees_east' 'C'
#  'degrees_north' 'degrees_east' '1' '1' '%' '%' '%' '%' '' 'cm/day'
#  '%/day' 'm' 'm' 'm' 'm' 'W/m^2' 'W/m^2' 'W/m^2' 'cm/day' 'd...
# 2  ['radians' 'radians' 'm' 'm' 'm' 'degrees_north' 'degrees_east' 'C'
#  'degrees_north' 'degrees_east' '1' '1' '%' '%' '%' '%' '' 'cm/day'
#  '%/day' 'm' 'm' 'm' 'm' 'W/m^2' 'W/m^2' 'W/m^2' 'cm/day' 'd...
# 3  ['yr' 'days' 'days since 1900-01-01 00:00:00'
#  'days since 1900-01-01 00:00:00' 'm' 'degrees_E' 'degrees_E' 'degrees_N'
#  'degrees_N' 'kg/m^3' 'kg/m^3' 'none' 'kg/m^3' 'degrees K' 'kg/m^3'
#  'kg/m^3...
# 4  ['m^2' 'm^2' 'dimensionless' 'm' 'm' 'm' 'm' 'degrees_N' 'degrees_N'
#  'degrees_E' 'degrees_E' 'm' 'm' 'dimensionless' 'dimensionless'
#  'days since 1900-01-01 00:00:00' 'degrees_E' 'degrees_E' 'deg...
#
#     realm
# 0  seaIce
# 1  seaIce
# 2  seaIce
# 3   ocean
# 4   ocean

# %% [markdown]
# ## 5. Finding all variables in an experiment
#
# You can get a list of all available variable names from an experiment with:

# %%
variables = catalog.search(name=experiment).unique().variable
print(variables)
# Out:
# ['total_ocean_melt', 'total_ocean_calving_heat', 'xu_ocean', 'bih_fric_u', 'u', 'total_ocean_evap_heat', 'HTN', 'total_ocean_salt', 'passive_adelie', 'aicen_m', 'grid_yt_ocean', 'total_ocean_runoff_heat', 'alidf_ai_m', 'average_T2', 'sfc_hflux_pme', 'sss_m', 'yt_ocean_sub02', 'tmask', 'area_t', 'total_ocean_sens_heat', 'xt_ocean_sub01', 'opening_m', 'total_net_sfc_heating', 'blkmask', 'vatm_m', 'wt', 'vhrho_nt', 'fmelttn_ai_m', 'temp_tendency', 'total_ocean_calving', 'total_ocean_swflx_vis', 'geolon_t', 'scalar_axis', 'temp_advection', 'fprec_melt_heat', 'total_ocean_swflx', 'TLON', 'HTE', 'pe_tot', 'temp_yflux_adv', 'eta_t', 'pme_river', 'tx_trans_submeso', 'sig1_m', 'total_ocean_fprec', 'temp_nonlocal_KPP', 'alvdf_ai_m', 'ty_trans_nrho_submeso', 'sfc_salt_flux_restore', 'pbot_t', 'yt_ocean_sub01', 'NCAT', 'total_ocean_sfc_salt_flux_coupler', 'total_ocean_fprec_melt_heat', 'temp_rivermix', 'sfc_salt_flux_coupler', 'passive_prydz', 'surface_salt', 'ke_tot', 'sea_levelsq', 'neutral', 'tarea', 'dyt', 'temp', 'total_ocean_river', 'fsalt_ai_m', 'temp_xflux_adv', 'yu_ocean_sub02', 'sfc_hflux_from_runoff', 'dxu', 'pot_rho_2', 'grid_xt_ocean', 'salt_global_ave', 'xu_ocean_sub02', 'alidr_ai_m', 'fsalt_m', 'eta_global', 'age_global', 'st_edges_ocean', 'strairx_m', 'ANGLE', 'tx_trans_rho', 'potrho', 'runoff', 'total_ocean_lw_heat', 'st_ocean', 'salt', 'temp_global_ave', 'alvdr_ai_m', 'TLAT', 'ty_trans_submeso', 'total_ocean_runoff', 'time', 'vsurf', 'fswup_m', 'lprec', 'tx_trans_int_z', 'sw_edges_ocean', 'fmeltt_ai_m', 'ty_trans_rho', 'rhoave', 'shear_m', 'hu', 'sens_heat', 'sea_level', 'geolon_c', 'total_ocean_lprec', 'v', 'temp_surface_ave', 'sfc_salt_flux_ice', 'xt_ocean_sub02', 'frazil_m', 'evap_heat', 'sfc_hflux_coupler', 'total_ocean_evap', 'vert_pv', 'sw_ocean', 'river', 'sst_m', 'yu_ocean_sub01', 'uhrho_et', 'total_ocean_hflux_coupler', 'total_ocean_pme_river', 'uarea', 'Tsfc_m', 'xu_ocean_sub01', 'ANGLET', 'yt_ocean', 'u_dot_grad_vert_pv', 'frazil_3d_int_z', 'passive_weddell', 'frazil_3d', 'kmt', 'surface_temp', 'bih_fric_v', 'salt_surface_ave', 'melt', 'ty_trans', 'geolat_t', 'temp_vdiffuse_impl', 'pme_net', 'potrho_edges', 'time_bounds', 'fprec', 'dyu', 'aice_m', 'ht', 'sig2_m', 'divu_m', 'pot_rho_1', 'wfimelt', 'buoyfreq2_wt', 'ULAT', 'tau_y', 'total_ocean_hflux_evap', 'grid_xu_ocean', 'tx_trans', 'wfiform', 'dxt', 'flatn_ai_m', 'congel_m', 'dzt', 'vvel_m', 'grid_yu_ocean', 'xt_ocean', 'usurf', 'passive_ross', 'total_ocean_river_heat', 'total_ocean_calving_melt_heat', 'vocn_m', 'lw_heat', 'neutralrho_edges', 'uocn_m', 'uatm_m', 'frz_onset_m', 'pot_temp', 'drag_coeff', 'rho', 'nv', 'strength_m', 'uvel_m', 'ty_trans_int_z', 'hs_m', 'average_DT', 'tau_x', 'mlt_onset_m', 'evap', 'swflx', 'vicen_m', 'geolat_c', 'yu_ocean', 'average_T1', 'ULON', 'total_ocean_hflux_prec', 'strairy_m', 'pot_rho_0', 'net_sfc_heating', 'temp_vdiffuse_diff_cbt_conv', 'kmu', 'total_ocean_heat', 'hi_m', 'area_u', 'temp_submeso', 'mld', 'sw_heat']

# %% [markdown]
# ### We could similarly filter for any of the keys in our catalog - see the intake dataframe catalog below

# %%
catalog.search(name=experiment)
# Out:
# <p><strong>Intake dataframe catalog with 1 source(s) across 6 rows</strong>:</p> <div style='max-height: 300px; overflow: auto; width: fit-content'><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>model</th>
#       <th>description</th>
#       <th>realm</th>
#       <th>frequency</th>
#       <th>variable</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>01deg_jra55v13_ryf9091</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991)}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1mon, 3hr, fx, 1day, 3mon}</td>
#       <td>{total_ocean_melt, total_ocean_calving_heat, xu_ocean, bih_fric_u, u, total_ocean_evap_heat, HTN, total_ocean_salt, passive_adelie, aicen_m, grid_yt_ocean, total_ocean_runoff_heat, alidf_ai_m, ave...</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>

# %%
catalog.search(name=experiment, realm = 'ocean')
# Out:
# <p><strong>Intake dataframe catalog with 1 source(s) across 5 rows</strong>:</p> <div style='max-height: 300px; overflow: auto; width: fit-content'><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>model</th>
#       <th>description</th>
#       <th>realm</th>
#       <th>frequency</th>
#       <th>variable</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>01deg_jra55v13_ryf9091</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991)}</td>
#       <td>{ocean}</td>
#       <td>{1mon, 3hr, fx, 1day, 3mon}</td>
#       <td>{total_ocean_melt, total_ocean_calving_heat, xu_ocean, bih_fric_u, u, total_ocean_evap_heat, total_ocean_salt, passive_adelie, grid_yt_ocean, total_ocean_runoff_heat, average_T2, sfc_hflux_pme, yt...</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>

# %%
# Lets pull out all the unique frequencies, just like we did for variable above
catalog.search(name=experiment, realm='ocean').unique().frequency
# Out:
# ['1mon', '3hr', 'fx', '1day', '3mon']

# %% [markdown]
# We could also open the experiment (using square brackets) to search for variables, frequencies, etc. - but this opens the datastore: see how the output of the cell below is displayed differently.
#
# If we open the datastore:
# 1. It is slower - opening datastores requires extra work
# 2. The items we can search on might change - the datastore below contains no model field, for example.
#
# The opened datastore can contain extra information, eg. `variable_long_name` below - so sometimes you might want to open it to search the datastore. In general, try to use `catalog.search(name='xyz',...)` before you use `catalog['xyz'].search(...)`, though.

# %%
catalog[experiment]
# Out:
# <p><strong>01deg_jra55v13_ryf9091 catalog with 22 dataset(s) from 11947 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>filename</th>
#       <td>3469</td>
#     </tr>
#     <tr>
#       <th>path</th>
#       <td>11947</td>
#     </tr>
#     <tr>
#       <th>file_id</th>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>start_date</th>
#       <td>3361</td>
#     </tr>
#     <tr>
#       <th>end_date</th>
#       <td>3360</td>
#     </tr>
#     <tr>
#       <th>variable</th>
#       <td>205</td>
#     </tr>
#     <tr>
#       <th>variable_long_name</th>
#       <td>197</td>
#     </tr>
#     <tr>
#       <th>variable_standard_name</th>
#       <td>36</td>
#     </tr>
#     <tr>
#       <th>variable_cell_methods</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>variable_units</th>
#       <td>52</td>
#     </tr>
#     <tr>
#       <th>realm</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>derived_variable</th>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# For more information about the available variables, you can use the following command function - just copy and paste it in where you need it:

# %%
def get_detailed_variable_info(intake_catalog, experiment_name : str, variable : str | None = None) -> "pd.Dataframe":
    """
    Get detailed information about all the variables available in an experiment contained within the catalog.

    If a specific variable is passed, then the returned dataframe will be filtered to include only information
    about that variable

    Returns a pandas dataframe, reorganised to use the variable as the index.

    Parameters:
    -----------
    intake_catalog: 
        The variable holding the intake catalog. If you have opened the catalog using
        `cat = intake.cat.access_nri`, then `intake_catalog=cat`, etc.
    experiment_name: str
        The name of the experiment you are interested in. Eg. `experiment = "01deg_jra55v13_ryf9091"`
    variable: str | None
        If you want detailed information about just a single variable, then pass it here. For 
        example, if you only want information about potential temperature, pass `variable='pot_temp'`
    """

    expt_ds = intake_catalog[experiment_name]
    columns_with_iterables = list(expt_ds.esmcat.columns_with_iterables)
    variable_column_name = expt_ds.esmcat.aggregation_control.variable_column_name
    
    df = expt_ds.df.copy()
    if columns_with_iterables:
        df = df.explode(columns_with_iterables, ignore_index=True)
    df.index = df[variable_column_name]
    df.drop(columns=variable_column_name, inplace=True)
    if variable is not None:
        df = df.loc[variable]
        
    return df

# %%
# To get detailed info about all variables
df = get_detailed_variable_info(catalog, experiment)
df.head(10)
# Out:
#
# variable
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...
# ['age_global' 'average_DT' 'average_T1' 'average_T2' 'dzt' 'grid_xt_ocean'
#  'grid_xu_ocean' 'grid_yt_ocean' 'grid_yu_ocean' 'neutral'
#  'neutralrho_edges' 'nv' 'pot_rho_0' 'pot_temp' 'potrho' 'potr...
# ['area_t' 'area_u' 'drag_coeff' 'dxt' 'dxu' 'dyt' 'dyu' 'geolat_c'
#  'geolat_t' 'geolon_c' 'geolon_t' 'ht' 'hu' 'kmt' 'kmu' 'time' 'xt_ocean'
#  'xu_ocean' 'yt_ocean' 'yu_ocean']
# ['average_DT' 'average_T1' 'average_T2' 'evap' 'evap_heat' 'fprec'
#  'fprec_melt_heat' 'frazil_3d_int_z' 'lprec' 'lw_heat' 'melt' 'mld'
#  'net_sfc_heating' 'nv' 'pbot_t' 'pme_net' 'pme_river' 'river...
# ['average_DT' 'average_T1' 'average_T2' 'eta_global' 'ke_tot' 'nv'
#  'pe_tot' 'rhoave' 'salt_global_ave' 'salt_surface_ave' 'scalar_axis'                                                                                                                                           filename  \
#  'temp_global_ave' 'temp_surface_ave' 'time' 'time_bounds'
# ...                                                                                                                                                                                                      iceh.1900-01.nc
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'                                                                                                                                iceh.1900-02.nc
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'                                                                                                                                  iceh.1900-03.nc
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...                                                                                                                                                           ocean.nc
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'                                                                                                                                  ocean_grid.nc
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'                                                                                                                                   ocean_month.nc
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...                                                                                                                                                    ocean_scalar.nc
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'                                                                                                                                iceh.1900-04.nc
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'                                                                                                                                  iceh.1900-05.nc
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...                                                                                                                                                    iceh.1900-06.nc
#
#
# variable
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...
# ['age_global' 'average_DT' 'average_T1' 'average_T2' 'dzt' 'grid_xt_ocean'
#  'grid_xu_ocean' 'grid_yt_ocean' 'grid_yu_ocean' 'neutral'
#  'neutralrho_edges' 'nv' 'pot_rho_0' 'pot_temp' 'potrho' 'potr...
# ['area_t' 'area_u' 'drag_coeff' 'dxt' 'dxu' 'dyt' 'dyu' 'geolat_c'
#  'geolat_t' 'geolon_c' 'geolon_t' 'ht' 'hu' 'kmt' 'kmu' 'time' 'xt_ocean'
#  'xu_ocean' 'yt_ocean' 'yu_ocean']
# ['average_DT' 'average_T1' 'average_T2' 'evap' 'evap_heat' 'fprec'
#  'fprec_melt_heat' 'frazil_3d_int_z' 'lprec' 'lw_heat' 'melt' 'mld'
#  'net_sfc_heating' 'nv' 'pbot_t' 'pme_net' 'pme_river' 'river...
# ['average_DT' 'average_T1' 'average_T2' 'eta_global' 'ke_tot' 'nv'
#  'pe_tot' 'rhoave' 'salt_global_ave' 'salt_surface_ave' 'scalar_axis'                                                                                                                                                                                                                                            path  \
#  'temp_global_ave' 'temp_surface_ave' 'time' 'time_bounds'
# ...                                                                                                                                                                                                      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v13_ryf9091/output000/ice/OUTPUT/iceh.1900-01.nc
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'                                                                                                                                /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v13_ryf9091/output000/ice/OUTPUT/iceh.1900-02.nc
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'                                                                                                                                  /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v13_ryf9091/output000/ice/OUTPUT/iceh.1900-03.nc
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...                                                                                                                                                                /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v13_ryf9091/output000/ocean/ocean.nc
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'                                                                                                                                       /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v13_ryf9091/output000/ocean/ocean_grid.nc
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'                                                                                                                                        /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v13_ryf9091/output000/ocean/ocean_month.nc
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...                                                                                                                                                         /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v13_ryf9091/output000/ocean/ocean_scalar.nc
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'                                                                                                                                /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v13_ryf9091/output001/ice/OUTPUT/iceh.1900-04.nc
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'                                                                                                                                  /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v13_ryf9091/output001/ice/OUTPUT/iceh.1900-05.nc
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...                                                                                                                                                    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v13_ryf9091/output001/ice/OUTPUT/iceh.1900-06.nc
#
#
# variable
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...
# ['age_global' 'average_DT' 'average_T1' 'average_T2' 'dzt' 'grid_xt_ocean'
#  'grid_xu_ocean' 'grid_yt_ocean' 'grid_yu_ocean' 'neutral'
#  'neutralrho_edges' 'nv' 'pot_rho_0' 'pot_temp' 'potrho' 'potr...
# ['area_t' 'area_u' 'drag_coeff' 'dxt' 'dxu' 'dyt' 'dyu' 'geolat_c'
#  'geolat_t' 'geolon_c' 'geolon_t' 'ht' 'hu' 'kmt' 'kmu' 'time' 'xt_ocean'
#  'xu_ocean' 'yt_ocean' 'yu_ocean']
# ['average_DT' 'average_T1' 'average_T2' 'evap' 'evap_heat' 'fprec'
#  'fprec_melt_heat' 'frazil_3d_int_z' 'lprec' 'lw_heat' 'melt' 'mld'
#  'net_sfc_heating' 'nv' 'pbot_t' 'pme_net' 'pme_river' 'river...
# ['average_DT' 'average_T1' 'average_T2' 'eta_global' 'ke_tot' 'nv'
#  'pe_tot' 'rhoave' 'salt_global_ave' 'salt_surface_ave' 'scalar_axis'                                                                                                                                                                                                                                                                                                                                    file_id  \
#  'temp_global_ave' 'temp_surface_ave' 'time' 'time_bounds'
# ...                                                                                                                                                                                                                                                                                                                                                                        seaIce.1mon.d2:2.nc:5.ni:3600.nj:2700
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'                                                                                                                                                                                                                                                                                                  seaIce.1mon.d2:2.nc:5.ni:3600.nj:2700
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'                                                                                                                                                                                                                                                                                                    seaIce.1mon.d2:2.nc:5.ni:3600.nj:2700
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...                                                                                                                                                    ocean.3mon.grid_xt_ocean:3600.grid_xu_ocean:3600.grid_yt_ocean:2700.grid_yu_ocean:2700.neutral:80.neutralrho_edges:81.nv:2.potrho:80.potrho_edges:81.st_edges_ocean:76.st_ocean:75.sw_edges_ocean:76...
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'                                                                                                                                                                                                                                                                       ocean.fx.xt_ocean:3600.xu_ocean:3600.yt_ocean:2700.yu_ocean:2700
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'                                                                                                                                                                                                                                                                  ocean.1mon.nv:2.xt_ocean:3600.xu_ocean:3600.yt_ocean:2700.yu_ocean:2700
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...                                                                                                                                                                                                                                                                                                                              ocean.1mon.nv:2.scalar_axis:1
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'                                                                                                                                                                                                                                                                                                  seaIce.1mon.d2:2.nc:5.ni:3600.nj:2700
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'                                                                                                                                                                                                                                                                                                    seaIce.1mon.d2:2.nc:5.ni:3600.nj:2700
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...                                                                                                                                                                                                                                                                                                                      seaIce.1mon.d2:2.nc:5.ni:3600.nj:2700
#
#
# variable
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...
# ['age_global' 'average_DT' 'average_T1' 'average_T2' 'dzt' 'grid_xt_ocean'
#  'grid_xu_ocean' 'grid_yt_ocean' 'grid_yu_ocean' 'neutral'
#  'neutralrho_edges' 'nv' 'pot_rho_0' 'pot_temp' 'potrho' 'potr...
# ['area_t' 'area_u' 'drag_coeff' 'dxt' 'dxu' 'dyt' 'dyu' 'geolat_c'
#  'geolat_t' 'geolon_c' 'geolon_t' 'ht' 'hu' 'kmt' 'kmu' 'time' 'xt_ocean'
#  'xu_ocean' 'yt_ocean' 'yu_ocean']
# ['average_DT' 'average_T1' 'average_T2' 'evap' 'evap_heat' 'fprec'
#  'fprec_melt_heat' 'frazil_3d_int_z' 'lprec' 'lw_heat' 'melt' 'mld'
#  'net_sfc_heating' 'nv' 'pbot_t' 'pme_net' 'pme_river' 'river...
# ['average_DT' 'average_T1' 'average_T2' 'eta_global' 'ke_tot' 'nv'
#  'pe_tot' 'rhoave' 'salt_global_ave' 'salt_surface_ave' 'scalar_axis'                                                                                                                                   frequency  \
#  'temp_global_ave' 'temp_surface_ave' 'time' 'time_bounds'
# ...                                                                                                                                                                                                          1mon
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'                                                                                                                                    1mon
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'                                                                                                                                      1mon
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...                                                                                                                                                        3mon
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'                                                                                                                                      fx
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'                                                                                                                                      1mon
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...                                                                                                                                                        1mon
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'                                                                                                                                    1mon
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'                                                                                                                                      1mon
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...                                                                                                                                                        1mon
#
#
# variable
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...
# ['age_global' 'average_DT' 'average_T1' 'average_T2' 'dzt' 'grid_xt_ocean'
#  'grid_xu_ocean' 'grid_yt_ocean' 'grid_yu_ocean' 'neutral'
#  'neutralrho_edges' 'nv' 'pot_rho_0' 'pot_temp' 'potrho' 'potr...
# ['area_t' 'area_u' 'drag_coeff' 'dxt' 'dxu' 'dyt' 'dyu' 'geolat_c'
#  'geolat_t' 'geolon_c' 'geolon_t' 'ht' 'hu' 'kmt' 'kmu' 'time' 'xt_ocean'
#  'xu_ocean' 'yt_ocean' 'yu_ocean']
# ['average_DT' 'average_T1' 'average_T2' 'evap' 'evap_heat' 'fprec'
#  'fprec_melt_heat' 'frazil_3d_int_z' 'lprec' 'lw_heat' 'melt' 'mld'
#  'net_sfc_heating' 'nv' 'pbot_t' 'pme_net' 'pme_river' 'river...
# ['average_DT' 'average_T1' 'average_T2' 'eta_global' 'ke_tot' 'nv'
#  'pe_tot' 'rhoave' 'salt_global_ave' 'salt_surface_ave' 'scalar_axis'                                                                                                                                              start_date  \
#  'temp_global_ave' 'temp_surface_ave' 'time' 'time_bounds'
# ...                                                                                                                                                                                                      1900-01-01, 00:00:00
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'                                                                                                                                1900-02-01, 00:00:00
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'                                                                                                                                  1900-03-01, 00:00:00
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...                                                                                                                                                    1900-01-01, 00:00:00
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'                                                                                                                                1900-04-01, 00:00:00
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'                                                                                                                                  1900-01-01, 00:00:00
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...                                                                                                                                                    1900-01-01, 00:00:00
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'                                                                                                                                1900-04-01, 00:00:00
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'                                                                                                                                  1900-05-01, 00:00:00
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...                                                                                                                                                    1900-06-01, 00:00:00
#
#
# variable
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...
# ...
# ['age_global' 'average_DT' 'average_T1' 'average_T2' 'dzt' 'grid_xt_ocean'
#  'grid_xu_ocean' 'grid_yt_ocean' 'grid_yu_ocean' 'neutral'
#  'neutralrho_edges' 'nv' 'pot_rho_0' 'pot_temp' 'potrho' 'potr...
# ['area_t' 'area_u' 'drag_coeff' 'dxt' 'dxu' 'dyt' 'dyu' 'geolat_c'
#  'geolat_t' 'geolon_c' 'geolon_t' 'ht' 'hu' 'kmt' 'kmu' 'time' 'xt_ocean'
#  'xu_ocean' 'yt_ocean' 'yu_ocean']
# ['average_DT' 'average_T1' 'average_T2' 'evap' 'evap_heat' 'fprec'
#  'fprec_melt_heat' 'frazil_3d_int_z' 'lprec' 'lw_heat' 'melt' 'mld'
#  'net_sfc_heating' 'nv' 'pbot_t' 'pme_net' 'pme_river' 'river...
# ['average_DT' 'average_T1' 'average_T2' 'eta_global' 'ke_tot' 'nv'
#  'pe_tot' 'rhoave' 'salt_global_ave' 'salt_surface_ave' 'scalar_axis'                                                                                                                                                                                                                                                                                                                             variable_units  \
#  'temp_global_ave' 'temp_surface_ave' 'time' 'time_bounds'
# ...                                                                                                                                                                                                      ['radians' 'radians' 'm' 'm' 'm' 'degrees_north' 'degrees_east' 'C'
#  'degrees_north' 'degrees_east' '1' '1' '%' '%' '%' '%' '' 'cm/day'
#  '%/day' 'm' 'm' 'm' 'm' 'W/m^2' 'W/m^2' 'W/m^2' 'cm/day' 'd...
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'                                                                                                                                ['radians' 'radians' 'm' 'm' 'm' 'degrees_north' 'degrees_east' 'C'
#  'degrees_north' 'degrees_east' '1' '1' '%' '%' '%' '%' '' 'cm/day'
#  '%/day' 'm' 'm' 'm' 'm' 'W/m^2' 'W/m^2' 'W/m^2' 'cm/day' 'd...
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'                                                                                                                                  ['radians' 'radians' 'm' 'm' 'm' 'degrees_north' 'degrees_east' 'C'
#  'degrees_north' 'degrees_east' '1' '1' '%' '%' '%' '%' '' 'cm/day'
#  '%/day' 'm' 'm' 'm' 'm' 'W/m^2' 'W/m^2' 'W/m^2' 'cm/day' 'd...
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...                                                                                                                                                    ['yr' 'days' 'days since 1900-01-01 00:00:00'
#  'days since 1900-01-01 00:00:00' 'm' 'degrees_E' 'degrees_E' 'degrees_N'
#  'degrees_N' 'kg/m^3' 'kg/m^3' 'none' 'kg/m^3' 'degrees K' 'kg/m^3'
#  'kg/m^3...
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'                                                                                                                                ['m^2' 'm^2' 'dimensionless' 'm' 'm' 'm' 'm' 'degrees_N' 'degrees_N'
#  'degrees_E' 'degrees_E' 'm' 'm' 'dimensionless' 'dimensionless'
#  'days since 1900-01-01 00:00:00' 'degrees_E' 'degrees_E' 'deg...
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'                                                                                                                                  ['days' 'days since 1900-01-01 00:00:00' 'days since 1900-01-01 00:00:00'
#  '(kg/m^3)*(m/sec)' 'W/m^2' '(kg/m^3)*(m/sec)' 'W/m^2' 'W/m^2'
#  '(kg/m^3)*(m/sec)' 'W/m^2' '(kg/m^3)*(m/sec)' 'm' 'Watts/m...
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...                                                                                                                                                    ['days' 'days since 1900-01-01 00:00:00' 'days since 1900-01-01 00:00:00'
#  'meter' '10^15 Joules' 'none' '10^15 Joules' 'kg/m^3' 'psu' 'psu' 'none'
#  'deg_C' 'deg_C' 'days since 1900-01-01 00:00:00...
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'                                                                                                                                ['radians' 'radians' 'm' 'm' 'm' 'degrees_north' 'degrees_east' 'C'
#  'degrees_north' 'degrees_east' '1' '1' '%' '%' '%' '%' '' 'cm/day'
#  '%/day' 'm' 'm' 'm' 'm' 'W/m^2' 'W/m^2' 'W/m^2' 'cm/day' 'd...
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'                                                                                                                                  ['radians' 'radians' 'm' 'm' 'm' 'degrees_north' 'degrees_east' 'C'
#  'degrees_north' 'degrees_east' '1' '1' '%' '%' '%' '%' '' 'cm/day'
#  '%/day' 'm' 'm' 'm' 'm' 'W/m^2' 'W/m^2' 'W/m^2' 'cm/day' 'd...
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...                                                                                                                                                    ['radians' 'radians' 'm' 'm' 'm' 'degrees_north' 'degrees_east' 'C'
#  'degrees_north' 'degrees_east' '1' '1' '%' '%' '%' '%' '' 'cm/day'
#  '%/day' 'm' 'm' 'm' 'm' 'W/m^2' 'W/m^2' 'W/m^2' 'cm/day' 'd...
#
#
# variable
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...
# ['age_global' 'average_DT' 'average_T1' 'average_T2' 'dzt' 'grid_xt_ocean'
#  'grid_xu_ocean' 'grid_yt_ocean' 'grid_yu_ocean' 'neutral'
#  'neutralrho_edges' 'nv' 'pot_rho_0' 'pot_temp' 'potrho' 'potr...
# ['area_t' 'area_u' 'drag_coeff' 'dxt' 'dxu' 'dyt' 'dyu' 'geolat_c'
#  'geolat_t' 'geolon_c' 'geolon_t' 'ht' 'hu' 'kmt' 'kmu' 'time' 'xt_ocean'
#  'xu_ocean' 'yt_ocean' 'yu_ocean']
# ['average_DT' 'average_T1' 'average_T2' 'evap' 'evap_heat' 'fprec'
#  'fprec_melt_heat' 'frazil_3d_int_z' 'lprec' 'lw_heat' 'melt' 'mld'
#  'net_sfc_heating' 'nv' 'pbot_t' 'pme_net' 'pme_river' 'river...
# ['average_DT' 'average_T1' 'average_T2' 'eta_global' 'ke_tot' 'nv'
#  'pe_tot' 'rhoave' 'salt_global_ave' 'salt_surface_ave' 'scalar_axis'                                                                                                                                     realm
#  'temp_global_ave' 'temp_surface_ave' 'time' 'time_bounds'
# ...                                                                                                                                                                                                      seaIce
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'                                                                                                                                seaIce
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'                                                                                                                                  seaIce
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...                                                                                                                                                     ocean
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'                                                                                                                                 ocean
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'                                                                                                                                   ocean
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...                                                                                                                                                     ocean
# ['ANGLE' 'ANGLET' 'HTE' 'HTN' 'NCAT' 'TLAT' 'TLON' 'Tsfc_m' 'ULAT' 'ULON'                                                                                                                                seaIce
#  'aice_m' 'aicen_m' 'alidf_ai_m' 'alidr_ai_m' 'alvdf_ai_m' 'alvdr_ai_m'                                                                                                                                  seaIce
#  'blkmask' 'congel_m' 'divu_m' 'dxt' 'dxu' 'dyt' '...                                                                                                                                                    seaIce

# %%
# Say we were only interested in zonal wind stress:
df = get_detailed_variable_info(catalog, experiment, 'tau_x')
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 # Say we were only interested in zonal wind stress:
# ----> 2 df = get_detailed_variable_info(catalog, experiment, 'tau_x')
#       3 df.head(10)
#
# Cell In[27], line 32, in get_detailed_variable_info(intake_catalog, experiment_name, variable)
#      30 df.drop(columns=variable_column_name, inplace=True)
#      31 if variable is not None:
# ---> 32     df = df.loc[variable]
#      34 return df
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/pandas/core/indexing.py:1431, in _LocIndexer._getitem_axis(self, key, axis)
#    1429 # fall thru to straight lookup
#    1430 self._validate_key(key, axis)
# -> 1431 return self._get_label(key, axis=axis)
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/pandas/core/indexing.py:1381, in _LocIndexer._get_label(self, label, axis)
#    1379 def _get_label(self, label, axis: AxisInt):
#    1380     # GH#5567 this will fail if the label is not present in the axis.
# -> 1381     return self.obj.xs(label, axis=axis)
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/pandas/core/generic.py:4320, in NDFrame.xs(self, key, axis, level, drop_level)
#    4318             new_index = index[loc]
#    4319 else:
# -> 4320     loc = index.get_loc(key)
#    4322     if isinstance(loc, np.ndarray):
#    4323         if loc.dtype == np.bool_:
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3810 casted_key = self._maybe_cast_indexer(key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:189, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:333, in pandas._libs.index.IndexEngine._ensure_mapping_populated()
#
# File pandas/_libs/hashtable_class_helper.pxi:7122, in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'numpy.ndarray'

# %% [markdown]
# If you have any further questions after reading this notebook and the documentation linked from this notebook, please open an issue in the [ACCESS-NRI Intake catalog Github repo](https://github.com/ACCESS-NRI/access-nri-intake-catalog) or open topic on the [ACCESS-Hive forum](https://forum.access-hive.org.au/).

# %%
client.close()
