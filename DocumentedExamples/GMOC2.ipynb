# %% [markdown]
# # Zonally Averaged Overturning Circulation
#
# This notebook shows a simple example of calculation the zonally averaged global meridional overturning circulation - in density space - using output from either `MOM5` or `MOM6`.
#
# **Requirements:** The `conda/analysis3` (or later) module on ARE. I recommend an ARE session with more than 14 cores to make these computations.
#
# **Firstly,** load in the requisite libraries:

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

import cosima_cookbook as cc
import matplotlib.pyplot as plt
import cmocean as cm
import numpy as np
from dask.distributed import Client
import xarray as xr
import cf_xarray as cfxr

# %%
client = Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:37103' processes=7 threads=28, memory=251.20 GiB>

# %% [markdown]
# **At this stage**, you need to denote whether the experiment uses output from `MOM5` or `MOM6`.
#
# This notebook is designed to use `cf-xarray` and a dictionary of `querying.getvar` arguments to load the correct variables independent of the model.

# %%
session = cc.database.create_session()

# %% [markdown]
# **Next,** choose an experiment. The dictionary below denotes which experiment we want to use for each model.
#
# We can choose experiments at any resolution. For MOM5-based runs, they can be with or without Gent-McWilliams eddy parameterisation.
#
# For this example, we are choosing to limit ourselves to just the last 20 years of the 0.25° control simulations. If you want to increase the resolution or integrate over a longer time you might need more resources!

# %%
psi_args = {
    "mom5": {
        "expt": "01deg_jra55v13_ryf9091",
        "variable": "ty_trans_rho",
        "start_time": "2152-01-01",
        "end_time": "2154-12-31"
    },
    "mom6": {
        "expt": "OM4_025.JRA_RYF",
        "variable": "vmo",
        "start_time": "1980-01-01",
        "end_time": "2000-01-01",
        "frequency": "1 monthly",
        "attrs": {"cell_methods": "rho2_l:sum yq:point xh:sum time: mean"},
    }
}

# %% [markdown]
# MOM5: Load up `ty_trans_rho` - and sum zonally.
# Also, if there is a `ty_trans_rho_gm` variable saved, assume that GM is switched on and load that as well. Most ACCESS-OM2 and MOM6 simulations save transport with units of kg/s - convert to Sv.

# %%
def load_streamfunction(model):
    expt = psi_args[model]["expt"]
    start_time = psi_args[model]["start_time"]
    end_time = psi_args[model]["end_time"]

    psi = cc.querying.getvar(session=session, **psi_args[model])
    psi = psi.sel(time=slice(start_time, end_time))
    psi = psi.cf.sum("longitude")

    psiGM = xr.zeros_like(psi)

    varlist = cc.querying.get_variables(session, expt)
    if varlist['name'].str.contains('ty_trans_rho_gm').any():
        GM = True
        psiGM = cc.querying.getvar(expt, 'ty_trans_rho_gm', session, start_time=start_time)
        psiGM = psiGM.cf.sum("longitude")
    else:
        GM = False
    
    ρ0 = 1025 # mean density of sea-water [kg/m³]
    
    psi = psi / (1e6 * ρ0)
    psiGM = psiGM / (1e6 * ρ0)
    
    return psi, psiGM, GM

# %% [markdown]
# Now, we define a function that cumulatively sums the transport in the vertical. Note that in MOM5 the `ty_trans_rho_GM` variable is computed differently and **does not** require summing in the vertical. Once the calculation has been laid out, we then load the variable to force the computation to occur.

# %%
def sum_in_vertical(psi, psiGM, GM):
    psi_avg = psi.cf.cumsum("vertical").mean("time") - psi.cf.sum("vertical").mean("time")

    if GM:
        psi_avg = psi_avg + psiGM.cf.mean("time")

    psi_avg.load()
    
    return psi_avg

# %% [markdown]
# Let's load everything from a MOM5 model.

# %%
model = 'mom5'
psi, psiGM, GM = load_streamfunction(model)
psi_avg = sum_in_vertical(psi, psiGM, GM)
# Out:
# 2023-06-27 22:48:23,662 - distributed.utils_perf - WARNING - full garbage collections took 43% CPU time recently (threshold: 10%)
# 2023-06-27 22:48:47,930 - distributed.utils_perf - WARNING - full garbage collections took 43% CPU time recently (threshold: 10%)
# 2023-06-27 22:49:13,461 - distributed.utils_perf - WARNING - full garbage collections took 43% CPU time recently (threshold: 10%)
# 2023-06-27 22:49:38,618 - distributed.utils_perf - WARNING - full garbage collections took 43% CPU time recently (threshold: 10%)
# 2023-06-27 22:49:45,194 - distributed.utils_perf - WARNING - full garbage collections took 45% CPU time recently (threshold: 10%)
# 2023-06-27 22:50:02,637 - distributed.utils_perf - WARNING - full garbage collections took 43% CPU time recently (threshold: 10%)
# 2023-06-27 22:50:08,569 - distributed.utils_perf - WARNING - full garbage collections took 47% CPU time recently (threshold: 10%)
# 2023-06-27 22:50:25,759 - distributed.utils_perf - WARNING - full garbage collections took 44% CPU time recently (threshold: 10%)
# 2023-06-27 22:50:36,764 - distributed.utils_perf - WARNING - full garbage collections took 48% CPU time recently (threshold: 10%)
# 2023-06-27 22:50:54,051 - distributed.utils_perf - WARNING - full garbage collections took 45% CPU time recently (threshold: 10%)
# 2023-06-27 22:50:56,160 - distributed.utils_perf - WARNING - full garbage collections took 39% CPU time recently (threshold: 10%)
# 2023-06-27 22:50:57,134 - distributed.utils_perf - WARNING - full garbage collections took 39% CPU time recently (threshold: 10%)
# 2023-06-27 22:51:06,059 - distributed.utils_perf - WARNING - full garbage collections took 48% CPU time recently (threshold: 10%)
# 2023-06-27 22:51:12,566 - distributed.utils_perf - WARNING - full garbage collections took 40% CPU time recently (threshold: 10%)
# 2023-06-27 22:51:20,312 - distributed.utils_perf - WARNING - full garbage collections took 46% CPU time recently (threshold: 10%)
# 2023-06-27 22:51:23,069 - distributed.utils_perf - WARNING - full garbage collections took 39% CPU time recently (threshold: 10%)
# 2023-06-27 22:51:29,423 - distributed.utils_perf - WARNING - full garbage collections took 39% CPU time recently (threshold: 10%)
# 2023-06-27 22:51:36,085 - distributed.utils_perf - WARNING - full garbage collections took 48% CPU time recently (threshold: 10%)
# 2023-06-27 22:51:40,228 - distributed.utils_perf - WARNING - full garbage collections took 40% CPU time recently (threshold: 10%)
# 2023-06-27 22:51:48,719 - distributed.utils_perf - WARNING - full garbage collections took 47% CPU time recently (threshold: 10%)
# 2023-06-27 22:51:55,343 - distributed.utils_perf - WARNING - full garbage collections took 39% CPU time recently (threshold: 10%)
# 2023-06-27 22:52:05,068 - distributed.utils_perf - WARNING - full garbage collections took 49% CPU time recently (threshold: 10%)
# 2023-06-27 22:52:05,598 - distributed.utils_perf - WARNING - full garbage collections took 39% CPU time recently (threshold: 10%)
# 2023-06-27 22:52:08,840 - distributed.utils_perf - WARNING - full garbage collections took 41% CPU time recently (threshold: 10%)
# 2023-06-27 22:52:17,261 - distributed.utils_perf - WARNING - full garbage collections took 48% CPU time recently (threshold: 10%)
# 2023-06-27 22:52:29,540 - distributed.utils_perf - WARNING - full garbage collections took 39% CPU time recently (threshold: 10%)
# 2023-06-27 22:52:32,379 - distributed.utils_perf - WARNING - full garbage collections took 50% CPU time recently (threshold: 10%)
# 2023-06-27 22:52:37,034 - distributed.utils_perf - WARNING - full garbage collections took 42% CPU time recently (threshold: 10%)
# 2023-06-27 22:52:42,353 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2023-06-27 22:52:46,414 - distributed.utils_perf - WARNING - full garbage collections took 48% CPU time recently (threshold: 10%)
# 2023-06-27 22:53:00,360 - distributed.utils_perf - WARNING - full garbage collections took 46% CPU time recently (threshold: 10%)
# 2023-06-27 22:53:02,944 - distributed.utils_perf - WARNING - full garbage collections took 39% CPU time recently (threshold: 10%)
# 2023-06-27 22:53:03,917 - distributed.utils_perf - WARNING - full garbage collections took 50% CPU time recently (threshold: 10%)
# 2023-06-27 22:53:06,777 - distributed.utils_perf - WARNING - full garbage collections took 42% CPU time recently (threshold: 10%)
# 2023-06-27 22:53:15,644 - distributed.utils_perf - WARNING - full garbage collections took 48% CPU time recently (threshold: 10%)
# 2023-06-27 22:53:20,206 - distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# 2023-06-27 22:53:36,886 - distributed.utils_perf - WARNING - full garbage collections took 46% CPU time recently (threshold: 10%)
# 2023-06-27 22:53:45,337 - distributed.utils_perf - WARNING - full garbage collections took 50% CPU time recently (threshold: 10%)
# 2023-06-27 22:53:53,630 - distributed.utils_perf - WARNING - full garbage collections took 45% CPU time recently (threshold: 10%)
# 2023-06-27 22:53:54,784 - distributed.utils_perf - WARNING - full garbage collections took 43% CPU time recently (threshold: 10%)
# 2023-06-27 22:53:55,220 - distributed.utils_perf - WARNING - full garbage collections took 42% CPU time recently (threshold: 10%)
# 2023-06-27 22:53:57,725 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2023-06-27 22:54:03,178 - distributed.utils_perf - WARNING - full garbage collections took 45% CPU time recently (threshold: 10%)
# 2023-06-27 22:54:03,807 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2023-06-27 22:54:05,725 - distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# 2023-06-27 22:54:06,453 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2023-06-27 22:54:09,875 - distributed.utils_perf - WARNING - full garbage collections took 43% CPU time recently (threshold: 10%)
# 2023-06-27 22:54:09,992 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2023-06-27 22:54:13,453 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2023-06-27 22:54:14,256 - distributed.utils_perf - WARNING - full garbage collections took 45% CPU time recently (threshold: 10%)

# %% [markdown]
# Now we are ready to plot. We usually plot the streamfunction over a reduced range of density levels to highlight the deep ocean contribution...

# %%
rho2 = cc.querying.getvar(psi_args[model]["expt"], 'pot_rho_2', session, start_time=psi_args[model]["start_time"], end_time=psi_args[model]["end_time"])
rho2_mean = rho2.sel(time=slice(psi_args[model]["start_time"], psi_args[model]["end_time"])).mean('time')
rho2_zonal_mean = rho2_mean.cf.mean("longitude").load()
# Out:
# 2023-06-27 22:54:26,377 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2023-06-27 22:54:26,434 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2023-06-27 22:54:48,643 - distributed.utils_perf - WARNING - full garbage collections took 42% CPU time recently (threshold: 10%)
# 2023-06-27 22:54:48,711 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2023-06-27 22:54:48,722 - distributed.utils_perf - WARNING - full garbage collections took 45% CPU time recently (threshold: 10%)
# 2023-06-27 22:54:48,722 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2023-06-27 22:54:49,064 - distributed.utils_perf - WARNING - full garbage collections took 41% CPU time recently (threshold: 10%)
# 2023-06-27 22:54:54,091 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2023-06-27 22:54:55,467 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2023-06-27 22:54:56,630 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2023-06-27 22:54:57,016 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2023-06-27 22:54:58,431 - distributed.utils_perf - WARNING - full garbage collections took 44% CPU time recently (threshold: 10%)
# 2023-06-27 22:54:59,027 - distributed.utils_perf - WARNING - full garbage collections took 42% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:02,074 - distributed.utils_perf - WARNING - full garbage collections took 41% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:03,214 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:04,407 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:05,279 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:05,485 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:05,702 - distributed.utils_perf - WARNING - full garbage collections took 44% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:07,443 - distributed.utils_perf - WARNING - full garbage collections took 42% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:09,877 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:10,329 - distributed.utils_perf - WARNING - full garbage collections took 41% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:10,987 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:13,010 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:13,501 - distributed.utils_perf - WARNING - full garbage collections took 44% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:14,283 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:14,871 - distributed.utils_perf - WARNING - full garbage collections took 42% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:17,083 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:17,197 - distributed.utils_perf - WARNING - full garbage collections took 41% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:18,052 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:19,201 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:20,370 - distributed.utils_perf - WARNING - full garbage collections took 44% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:21,107 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:21,119 - distributed.utils_perf - WARNING - full garbage collections took 41% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:24,215 - distributed.utils_perf - WARNING - full garbage collections took 41% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:24,232 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:25,350 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:25,963 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:26,739 - distributed.utils_perf - WARNING - full garbage collections took 44% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:27,688 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:28,041 - distributed.utils_perf - WARNING - full garbage collections took 41% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:31,533 - distributed.utils_perf - WARNING - full garbage collections took 41% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:32,494 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:32,956 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:33,393 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:34,781 - distributed.utils_perf - WARNING - full garbage collections took 44% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:35,008 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:35,486 - distributed.utils_perf - WARNING - full garbage collections took 41% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:39,314 - distributed.utils_perf - WARNING - full garbage collections took 41% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:39,953 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:41,023 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:41,522 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:42,936 - distributed.utils_perf - WARNING - full garbage collections took 44% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:42,986 - distributed.utils_perf - WARNING - full garbage collections took 41% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:43,284 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:47,028 - distributed.utils_perf - WARNING - full garbage collections took 41% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:48,546 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:49,137 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:50,141 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:50,353 - distributed.utils_perf - WARNING - full garbage collections took 41% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:51,205 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:51,340 - distributed.utils_perf - WARNING - full garbage collections took 43% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:55,877 - distributed.utils_perf - WARNING - full garbage collections took 41% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:56,969 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:57,112 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:58,104 - distributed.utils_perf - WARNING - full garbage collections took 41% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:59,066 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2023-06-27 22:55:59,677 - distributed.utils_perf - WARNING - full garbage collections took 43% CPU time recently (threshold: 10%)
# 2023-06-27 22:56:00,007 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2023-06-27 22:56:04,148 - distributed.utils_perf - WARNING - full garbage collections took 41% CPU time recently (threshold: 10%)
# 2023-06-27 22:56:05,302 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2023-06-27 22:56:06,953 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2023-06-27 22:56:07,770 - distributed.utils_perf - WARNING - full garbage collections took 41% CPU time recently (threshold: 10%)
# 2023-06-27 22:56:08,753 - distributed.utils_perf - WARNING - full garbage collections took 43% CPU time recently (threshold: 10%)
# 2023-06-27 22:56:09,195 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2023-06-27 22:56:10,034 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2023-06-27 22:56:13,407 - distributed.utils_perf - WARNING - full garbage collections took 41% CPU time recently (threshold: 10%)
# 2023-06-27 22:56:14,834 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2023-06-27 22:56:16,684 - distributed.utils_perf - WARNING - full garbage collections took 40% CPU time recently (threshold: 10%)
# 2023-06-27 22:56:17,591 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2023-06-27 22:56:18,233 - distributed.utils_perf - WARNING - full garbage collections took 43% CPU time recently (threshold: 10%)
# 2023-06-27 22:56:19,432 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2023-06-27 22:56:19,852 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2023-06-27 22:56:23,251 - distributed.utils_perf - WARNING - full garbage collections took 40% CPU time recently (threshold: 10%)
# 2023-06-27 22:56:24,393 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2023-06-27 22:56:26,213 - distributed.utils_perf - WARNING - full garbage collections took 39% CPU time recently (threshold: 10%)
# 2023-06-27 22:56:28,185 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2023-06-27 22:56:28,321 - distributed.utils_perf - WARNING - full garbage collections took 42% CPU time recently (threshold: 10%)
# 2023-06-27 22:56:30,539 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2023-06-27 22:56:31,147 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2023-06-27 22:56:33,725 - distributed.utils_perf - WARNING - full garbage collections took 40% CPU time recently (threshold: 10%)
# 2023-06-27 22:56:34,776 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2023-06-27 22:56:37,069 - distributed.utils_perf - WARNING - full garbage collections took 39% CPU time recently (threshold: 10%)
# 2023-06-27 22:56:38,934 - distributed.utils_perf - WARNING - full garbage collections took 42% CPU time recently (threshold: 10%)
# 2023-06-27 22:56:39,668 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2023-06-27 22:56:42,150 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2023-06-27 22:56:42,286 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2023-06-27 22:56:45,974 - distributed.utils_perf - WARNING - full garbage collections took 40% CPU time recently (threshold: 10%)
# 2023-06-27 22:56:46,391 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2023-06-27 22:56:50,204 - distributed.utils_perf - WARNING - full garbage collections took 39% CPU time recently (threshold: 10%)
# 2023-06-27 22:56:50,267 - distributed.utils_perf - WARNING - full garbage collections took 42% CPU time recently (threshold: 10%)
# 2023-06-27 22:56:52,264 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2023-06-27 22:56:53,183 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2023-06-27 22:56:54,973 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2023-06-27 22:56:57,456 - distributed.utils_perf - WARNING - full garbage collections took 40% CPU time recently (threshold: 10%)
# 2023-06-27 22:56:58,817 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2023-06-27 22:57:02,701 - distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# 2023-06-27 22:57:02,805 - distributed.utils_perf - WARNING - full garbage collections took 42% CPU time recently (threshold: 10%)
# 2023-06-27 22:57:04,308 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2023-06-27 22:57:05,334 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2023-06-27 22:57:08,698 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2023-06-27 22:57:09,979 - distributed.utils_perf - WARNING - full garbage collections took 40% CPU time recently (threshold: 10%)
# 2023-06-27 22:57:11,547 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2023-06-27 22:57:15,203 - distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# 2023-06-27 22:57:15,376 - distributed.utils_perf - WARNING - full garbage collections took 41% CPU time recently (threshold: 10%)
# 2023-06-27 22:57:17,986 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2023-06-27 22:57:20,269 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2023-06-27 22:57:22,506 - distributed.utils_perf - WARNING - full garbage collections took 39% CPU time recently (threshold: 10%)
# 2023-06-27 22:57:23,749 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2023-06-27 22:57:24,953 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2023-06-27 22:57:28,508 - distributed.utils_perf - WARNING - full garbage collections took 42% CPU time recently (threshold: 10%)
# 2023-06-27 22:57:29,039 - distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# 2023-06-27 22:57:32,563 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2023-06-27 22:57:34,442 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2023-06-27 22:57:35,923 - distributed.utils_perf - WARNING - full garbage collections took 39% CPU time recently (threshold: 10%)
# 2023-06-27 22:57:38,766 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2023-06-27 22:57:39,815 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2023-06-27 22:57:43,446 - distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# 2023-06-27 22:57:43,465 - distributed.utils_perf - WARNING - full garbage collections took 41% CPU time recently (threshold: 10%)
# 2023-06-27 22:57:46,382 - distributed.utils_perf - WARNING - full garbage collections took 39% CPU time recently (threshold: 10%)
# 2023-06-27 22:57:51,910 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2023-06-27 22:57:53,072 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2023-06-27 22:57:53,743 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2023-06-27 22:57:55,318 - distributed.utils_perf - WARNING - full garbage collections took 39% CPU time recently (threshold: 10%)
# 2023-06-27 22:57:55,900 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2023-06-27 22:57:56,169 - distributed.utils_perf - WARNING - full garbage collections took 40% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:03,116 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:04,368 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:05,641 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:07,411 - distributed.utils_perf - WARNING - full garbage collections took 39% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:11,494 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:11,692 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:11,803 - distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:17,046 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:18,397 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:18,574 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:18,695 - distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:21,582 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:22,364 - distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:25,675 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:27,435 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:28,268 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:30,100 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:30,455 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:30,520 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:30,896 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:34,353 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:35,629 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:37,112 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:38,821 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:38,975 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:39,631 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:39,671 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:42,960 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:44,176 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:46,706 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:47,135 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:47,313 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:48,720 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:50,430 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:50,889 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:53,289 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:54,879 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:54,995 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:55,524 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:58,107 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2023-06-27 22:58:59,162 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2023-06-27 22:59:00,387 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2023-06-27 22:59:01,518 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2023-06-27 22:59:02,966 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2023-06-27 22:59:03,305 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2023-06-27 22:59:05,295 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2023-06-27 22:59:07,838 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2023-06-27 22:59:07,843 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2023-06-27 22:59:10,003 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2023-06-27 22:59:10,300 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2023-06-27 22:59:10,980 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2023-06-27 22:59:12,312 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2023-06-27 22:59:13,446 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2023-06-27 22:59:15,951 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2023-06-27 22:59:16,277 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2023-06-27 22:59:19,345 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2023-06-27 22:59:20,941 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2023-06-27 22:59:21,034 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2023-06-27 22:59:22,077 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2023-06-27 22:59:24,756 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2023-06-27 22:59:26,612 - distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# 2023-06-27 22:59:27,326 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2023-06-27 22:59:28,645 - distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)

# %%
from scipy.interpolate import interp1d
z1 = rho2_zonal_mean.st_ocean.values
psi_depth = psi_avg.copy()*0.0
for ii in range(59,2700):
    rho1 = rho2_zonal_mean.isel(yt_ocean=ii).values
    f = interp1d(rho1,z1,bounds_error=False,fill_value = (0,'NaN'))
    psi_depth[:,ii] = np.nan_to_num(f(psi_avg.potrho.values),nan=6000)

# %%
plt.plot(psi_depth.grid_yu_ocean,psi_depth.T.values);
plt.gca().invert_yaxis()

# %%
new_psi_avg = xr.DataArray(data=psi_avg.values,dims=["potrho", "grid_yu_ocean"],
            coords=dict(grid_yu_ocean=(["grid_yu_ocean"], psi_avg.grid_yu_ocean.values),
                        depth=(["potrho", "grid_yu_ocean"], psi_depth.values)),
                           attrs= psi_avg.attrs)

# %%
plt.figure(figsize=(10, 5))

max_psi = 24.5 # Sv

# how we compute the levels may seem complicated, we just want to avoid a 0 contour
# so that the plot looks soothing to the eye
levels =  np.hstack((np.arange(-max_psi, 0, 2), np.flip(-np.arange(-max_psi, 0, 2))))
cbarticks = np.hstack((np.flip(-np.arange(3, max_psi, 6)), np.arange(3, max_psi, 6)))

new_psi_avg.plot.contourf(y="depth",levels=levels,
                      cmap=cm.cm.curl, extend='both',
                      cbar_kwargs={'shrink': 0.7, 'label': 'Sv', 'ticks': cbarticks})
new_psi_avg.plot.contour(y="depth",levels=levels, colors='k', linewidths=0.25)

plt.gca().invert_yaxis()


plt.ylabel('Depth (m)')
plt.xlabel('Latitude ($^\circ$N)')
plt.xlim([-75, 80])
plt.title(f'Overturning in {model}: {psi_args[model]["expt"]}');

# %%
plt.figure(figsize=(10, 5))

max_psi = 24.5 # Sv

# how we compute the levels may seem complicated, we just want to avoid a 0 contour
# so that the plot looks soothing to the eye
levels =  np.hstack((np.arange(-max_psi, 0, 2), np.flip(-np.arange(-max_psi, 0, 2))))
cbarticks = np.hstack((np.flip(-np.arange(3, max_psi, 6)), np.arange(3, max_psi, 6)))

psi_avg.plot.contourf(levels=levels,
                      cmap=cm.cm.curl, extend='both',
                      cbar_kwargs={'shrink': 0.7, 'label': 'Sv', 'ticks': cbarticks})

psi_avg.plot.contour(levels=levels, colors='k', linewidths=0.25)

plt.gca().invert_yaxis()

plt.ylim((1037.5, 1034))
plt.ylabel('Potential Density (kg m$^{-3}$)')
plt.xlabel('Latitude ($^\circ$N)')
plt.xlim([-75, 80])
plt.title(f'Overturning in {model}: {psi_args[model]["expt"]}');

# %% [markdown]
# Now let's do it again from a MOM6 model. Easy!

# %%
model = 'mom6'
psi, psiGM, GM = load_streamfunction(model)
psi_avg = sum_in_vertical(psi, psiGM, GM)

# %%
plt.figure(figsize=(10, 5)) 

max_psi = 25 # Sv

# how we compute the levels may seem complicated, we just want to avoid a 0 contour
# so that the plot looks soothing to the eye
levels =  np.hstack((np.arange(-max_psi, 0, 2), np.flip(-np.arange(-max_psi, 0, 2))))
cbarticks = np.hstack((np.flip(-np.arange(3, max_psi, 6)), np.arange(3, max_psi, 6)))

psi_avg.plot.contourf(levels=levels,
                      cmap=cm.cm.curl, extend='both',
                      cbar_kwargs={'shrink': 0.7, 'label': 'Sv', 'ticks': cbarticks})

psi_avg.plot.contour(levels=levels, colors='k', linewidths=0.25)

plt.gca().invert_yaxis()

plt.ylim((1037.5, 1034))
plt.ylabel('Potential Density (kg m$^{-3}$)')
plt.xlabel('Latitude ($^\circ$N)')
plt.xlim([-75, 80])
plt.title(f'Overturning in {model}: {psi_args[model]["expt"]}');

# %% [markdown]
# Alternatively, you may want to stretch your axes to minimise the visual impact of the surface circulation, while showing the full-depth ocean.

# %%
stretching_factor = 4 # A powvalues set the stretching

ρmin = psi_avg.cf['vertical'].min()

psi_avg_plot = psi_avg.assign_coords(
    {
        psi_avg.cf["vertical"].name: (psi_avg.cf["vertical"] - ρmin)**stretching_factor
    }
)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))

max_psi = 24.5 # Sv

# how we compute the levels may seem complicated, we just want to avoid a 0 contour
# so that the plot looks soothing to the eye
levels =  np.hstack((np.arange(-max_psi, 0, 2), np.flip(-np.arange(-max_psi, 0, 2))))
cbarticks = np.hstack((np.flip(-np.arange(3, max_psi, 6)), np.arange(3, max_psi, 6)))

yticks = np.array([1030, 1032, 1033, 1034, 1035, 1036, 1036.5, 1037])

psi_avg_plot.plot.contourf(levels=levels, 
                           cmap=cm.cm.curl, extend='both',
                           cbar_kwargs={'shrink': 0.7,'label': 'Sv', 'ticks': cbarticks})

psi_avg_plot.plot.contour(levels=levels, colors='k', linewidths=0.25)

plt.gca().set_yticks((yticks - ρmin.values)**stretching_factor)
plt.gca().set_yticklabels(yticks)

# ylims: a bit less than the minimnum and a bit more than the maximum values
plt.gca().set_ylim([((yticks - ρmin.values).min() / 1.1)**stretching_factor, ((yticks - ρmin.values).max() * 1.02)**stretching_factor])
plt.gca().invert_yaxis()

plt.ylabel('Potential Density (kg m$^{-3}$)')
plt.xlabel('Latitude ($^\circ$N)')
plt.xlim([-75, 80])
plt.title(f'Overturning in {model}: {psi_args[model]["expt"]}');

# %% [markdown]
# **Notes:**
#
#  * We have not included the submesoscale contribution to the meridional transport in these calculations, as it tends to be relatively unimportant for the deep circulation, which we where we are primarily interested.
#
#  * These metrics do not use mathematically correct zonal averaging in the tripole region, north of 65°N!
